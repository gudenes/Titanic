# %% [markdown]
# 1. Exploratory data Analisys
#     Summary, Estatistics, value counts
#
# 2. GroupBy and Pivot Table
#
# 3. lambda function for Data transformation
#
# 4. Age, what to do with null values

# %%
import pandas as pd
import numpy as np

# %%
pd.set_option('max_rows', None)
pd.set_option('max_columns', None)

# %%
data = pd.read_csv("/home/gus/Dropbox/IRONHACK/LABS/train.csv")

# %%
data.shape
# Out:
# (891, 12)

# %%
data.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked
# 0      0  A/5 21171   7.2500   NaN        S
# 1      0   PC 17599  71.2833   C85        C

# %%
data.describe().T
# Out:
#              count        mean         std   min       25%       50%    75%  \
# PassengerId  891.0  446.000000  257.353842  1.00  223.5000  446.0000  668.5
# Survived     891.0    0.383838    0.486592  0.00    0.0000    0.0000    1.0
# Pclass       891.0    2.308642    0.836071  1.00    2.0000    3.0000    3.0
# Age          714.0   29.699118   14.526497  0.42   20.1250   28.0000   38.0
# SibSp        891.0    0.523008    1.102743  0.00    0.0000    0.0000    1.0
# Parch        891.0    0.381594    0.806057  0.00    0.0000    0.0000    0.0
# Fare         891.0   32.204208   49.693429  0.00    7.9104   14.4542   31.0
#
#                   max
# PassengerId  891.0000
# Survived       1.0000
# Pclass         3.0000
# Age           80.0000
# SibSp          8.0000
# Parch          6.0000
# Fare         512.3292

# %%
data["Survived"].value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
pd.pivot_table(data, index=[]"Survived","Pclass"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-133-64e886be0433> in <module>
# ----> 1 pd.pivot_table(data, index=["Survived","Pclass"], aggfunc=value_counts())
#
# NameError: name 'value_counts' is not defined

# %%
data["SibSp"].unique()
# Out:
# array([1, 0, 3, 4, 2, 5, 8])

# %%
data["Ticket"].value_counts()
# Out:
# 1601                  7
# CA. 2343              7
# 347082                7
# 3101295               6
# 347088                6
# CA 2144               6
# S.O.C. 14879          5
# 382652                5
# 349909                4
# 347077                4
# 17421                 4
# LINE                  4
# 4133                  4
# PC 17757              4
# W./C. 6608            4
# 113781                4
# 2666                  4
# 19950                 4
# 113760                4
# C.A. 31921            3
# C.A. 34651            3
# 110413                3
# 35273                 3
# 363291                3
# 230080                3
# F.C.C. 13529          3
# 347742                3
# 13502                 3
# 29106                 3
# 110152                3
# PC 17582              3
# PC 17572              3
# 239853                3
# 345773                3
# SC/Paris 2123         3
# 248727                3
# 24160                 3
# 371110                3
# ...

# %%
data["Sex"].value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
data["Embarked"].value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
data["Pclass"].value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
data.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
drop_cols = ["PassengerId","Name","Ticket","Embarked","Cabin"]

# %%
data.head()
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch     Fare
# 0         0       3    male  22.0      1      0   7.2500
# 1         1       1  female  38.0      1      0  71.2833
# 2         1       3  female  26.0      0      0   7.9250
# 3         1       1  female  35.0      1      0  53.1000
# 4         0       3    male  35.0      0      0   8.0500

# %%
data["Age"].value_counts(dropna=False).head()
# Out:
# NaN     177
# 24.0     30
# 22.0     27
# 18.0     26
# 28.0     25
# Name: Age, dtype: int64

# %%
ass = data.groupby(["Sex","Survived","Pclass"]).agg({"Survived":"count"})
ass["culo"] = ass["Survived"]*100/ass["Survived"].sum()
ass
# Out:
#                         Survived       culo
# Sex    Survived Pclass
# female 0        1              3   0.336700
#                 2              6   0.673401
#                 3             72   8.080808
#        1        1             91  10.213244
#                 2             70   7.856341
#                 3             72   8.080808
# male   0        1             77   8.641975
#                 2             91  10.213244
#                 3            300  33.670034
#        1        1             45   5.050505
#                 2             17   1.907969
#                 3             47   5.274972

# %%
data["Age"].value_counts(dropna=False).head()
# Out:
# NaN     177
# 24.0     30
# 22.0     27
# 18.0     26
# 28.0     25
# Name: Age, dtype: int64

# %%
labels = ["0 - 9","10 - 19", "20 - 29", "30 - 39", "40 - 49", "50+"]
cutoffs = [9,19,29,39,49,50,100]

# %%
bins = pd.cut(data['Age'],cutoffs, labels=labels)
bins.value_counts()
# Out:
# 10 - 19    220
# 20 - 29    167
# 0 - 9      102
# 30 - 39     89
# 50+         64
# 40 - 49     10
# Name: Age, dtype: int64
